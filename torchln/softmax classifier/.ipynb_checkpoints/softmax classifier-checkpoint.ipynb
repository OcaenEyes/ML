# %% [markdown]
# ![image.png](attachment:1277afe9-478e-4433-836c-99238a06a8e8.png)

# %%
import numpy as np

# %%
y = np.array([1,0,0])
z = np.array([0.2,0.1,-0.1])

# %%
y
# Out:
# array([1, 0, 0])

# %%
z
# Out:
# array([ 0.2,  0.1, -0.1])

# %%
y_pred = np.exp(z) / np.exp(z).sum()

# %%
y_pred
# Out:
# array([0.37797814, 0.34200877, 0.28001309])

# %%
loss = (-y * np.log(y_pred)).sum()

# %%
loss
# Out:
# 0.9729189131256584

# %% [markdown]
# ![image.png](attachment:dd28498c-a487-46bb-96f8-c9d7a4f7b963.png)

# %%
import torch

# %%
y = torch.LongTensor([0])

# %%
y
# Out:
# tensor([0])

# %%
z = torch.Tensor([[0.2,0.1,-0.1]])

# %%
z
# Out:
# tensor([[ 0.2000,  0.1000, -0.1000]])

# %%
criterion = torch.nn.CrossEntropyLoss()

# %%
loss = criterion(z,y)

# %%
loss
# Out:
# tensor(0.9729)

# %%
Y = torch.LongTensor([2,0,1])

# %%
Y
# Out:
# tensor([2, 0, 1])

# %%
Y_pred1 = torch.Tensor([[0.1, 0.2, 0.9],[1.1, 0.1, 0.2],[0.2, 2.1, 0.1]])

# %%
Y_pred1
# Out:
# tensor([[0.1000, 0.2000, 0.9000],
#         [1.1000, 0.1000, 0.2000],
#         [0.2000, 2.1000, 0.1000]])

# %%
Y_pred2 = torch.Tensor([[0.8,0.2,0.3],
                        [0.2,0.23,0.5],
                        [0.2,0.2,0.5]])

# %%
Y_pred2
# Out:
# tensor([[0.8000, 0.2000, 0.3000],
#         [0.2000, 0.2300, 0.5000],
#         [0.2000, 0.2000, 0.5000]])

# %%
loss1 = criterion(Y_pred1,Y)

# %%
loss1
# Out:
# tensor(0.4966)

# %%
loss2 = criterion(Y_pred2,Y)

# %%
loss2
# Out:
# tensor(1.2316)

# %%
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ### prepare dataset

# %%
batch_size = 64

# %% [markdown]
# ![image.png](attachment:ee3bb528-92f1-4a7e-9702-4699183c585a.png)

# %%
transform = transforms.Compose([transforms.ToTensor(),
                               transforms.Normalize((0.1307,),(0.3081,))
                               ])

# %%
transform
# Out:
# Compose(
#     ToTensor()
#     Normalize(mean=(0.1307,), std=(0.3081,))
# )

# %%
train_dataset = datasets.MNIST(root="../dataset/mnist/",
              train=True,
              download =True,
              transform=transform)
# Out:
# ...
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ../dataset/mnist/MNIST/raw/train-images-idx3-ubyte.gz to ../dataset/mnist/MNIST/raw
#
# ...
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ../dataset/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to ../dataset/mnist/MNIST/raw
#
# ...
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ../dataset/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to ../dataset/mnist/MNIST/raw
#
# ...
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ../dataset/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../dataset/mnist/MNIST/raw
# ...

# %%
train_dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ../dataset/mnist/
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#            )

# %%
train_loader = DataLoader(train_dataset,shuffle=True,batch_size=batch_size)

# %%
train_loader

# %%
test_dataset = datasets.MNIST(root="../dataset/mnist/",train=False,download=True,transform=transform)

# %%
test_dataset
# Out:
# Dataset MNIST
#     Number of datapoints: 10000
#     Root location: ../dataset/mnist/
#     Split: Test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.1307,), std=(0.3081,))
#            )

# %%
test_loader = DataLoader(test_dataset,shuffle=False,batch_size=batch_size)

# %%
test_loader

# %% [markdown]
# ![image.png](attachment:f04604d5-ceb9-49f1-b48d-2969263582dd.png)

# %% [markdown]
# ### design model

# %%
class ModelNet(torch.nn.Module):
    def __init__(self):
        super(ModelNet,self).__init__()
        
        self.l1 = torch.nn.Linear(784,512)
        self.l2 = torch.nn.Linear(512,256)
        self.l3 = torch.nn.Linear(256,128)
        self.l4 = torch.nn.Linear(128,64)
        self.l5 = torch.nn.Linear(64,10)
        
    def forward(self,x):
        x = x.view(-1,784)
        x = F.relu(self.l1(x))
        x = F.relu(self.l2(x))        
        x = F.relu(self.l3(x))        
        x = F.relu(self.l4(x))  
        return self.l5(x)

# %%
model = ModelNet()

# %%
model
# Out:
# ModelNet(
#   (l1): Linear(in_features=784, out_features=512, bias=True)
#   (l2): Linear(in_features=512, out_features=256, bias=True)
#   (l3): Linear(in_features=256, out_features=128, bias=True)
#   (l4): Linear(in_features=128, out_features=64, bias=True)
#   (l5): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
model.parameters
# Out:
# <bound method Module.parameters of ModelNet(
#   (l1): Linear(in_features=784, out_features=512, bias=True)
#   (l2): Linear(in_features=512, out_features=256, bias=True)
#   (l3): Linear(in_features=256, out_features=128, bias=True)
#   (l4): Linear(in_features=128, out_features=64, bias=True)
#   (l5): Linear(in_features=64, out_features=10, bias=True)
# )>

# %% [markdown]
# ### contruct loss and optimizer

# %% [markdown]
# ![image.png](attachment:5bb92123-6d04-447d-9647-4487c113692c.png)

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(),lr=0.1,momentum=0.5)

# %%
criterion
# Out:
# CrossEntropyLoss()

# %%
optimizer
# Out:
# SGD (
# Parameter Group 0
#     dampening: 0
#     lr: 0.1
#     momentum: 0.5
#     nesterov: False
#     weight_decay: 0
# )

# %% [markdown]
# ### train and test

# %%
def train(epoch):
    run_loss = 0.0
    for batch_idx,data in enumerate(train_loader):
        inputs,target = data
        optimizer.zero_grad()  #梯度提前归0
        
        # forward + backward + update
        outputs = model(inputs)
        loss = criterion(outputs,target)
        loss.backward()
        optimizer.step()
        
        
        run_loss += loss.item()
        if batch_idx %300 ==299:
            print("[%d, %5d] loss: %.3f" % (epoch+1,batch_idx+1,run_loss/300))
            run_loss =0.0

# %%
def test():
    correct =0 
    total = 0
    with torch.no_grad():
        for data in test_loader:
            images,labels = data
            outputs = model(images)
            print(torch.max(outputs.data,dim=1))
            _,predicted = torch.max(outputs.data,dim=1)
            
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    print("accuracy on test set : %d %%"%(100 * correct / total))

# %%
for epoch in range(10):
    train(epoch)
    test()
