# %%
import pandas as pd
import json

# %%
data = pd.read_json("efaqa-corpus-zh.utf8",lines=True)

# %%
data
# Out:
#                                                    chats                date  \
# 0      [{'label': {'knowledge': False, 'negative': Fa... 2020-03-02 11:01:08
# 1      [{'label': {'knowledge': False, 'negative': Fa... 2020-03-01 23:35:12
# 2      [{'label': {'knowledge': False, 'negative': Fa... 2020-03-01 22:27:12
# 3      [{'label': {'attitude': '', 's3': ''}, 'sender... 2020-02-29 23:02:53
# 4      [{'label': {'knowledge': False, 'negative': Fa... 2020-02-29 22:52:49
# ...                                                  ...                 ...
# 19995  [{'label': {'knowledge': False, 'negative': Fa... 2016-06-28 22:58:46
# 19996  [{'label': {'knowledge': True, 'negative': Fal... 2016-07-15 22:29:13
# 19997  [{'label': {'knowledge': False, 'negative': Fa... 2016-07-08 00:23:29
# 19998  [{'label': {'knowledge': False, 'negative': Fa... 2016-06-29 23:59:28
# 19999  [{'label': {'knowledge': False, 'negative': Fa... 2016-07-01 23:07:03
#
# ...
